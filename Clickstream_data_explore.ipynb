# %% [markdown]
# # Clickstream data
# Collected between June 2017 to July 2018 using the Robin tool

# %% [markdown]
# Import libraries and dependecies

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Load the clickstream dataset from from the csv file "HBI_clickstream_june17tojan18.csv". this csv file is not in github since it containes private data. You need to add it to your local repository after cloning it this one)

# %%
clickstream_data = pd.read_csv("HBI_clickstream_june17tojan18.csv") 
clickstream_data.sample(50)
# Out:
#     Unnamed: 0                               API_key  Unnamed: 0.1  \
# 0            0  020bce8e-f76f-4e45-8572-147541079bb5        2222.0
# 1            1  020bce8e-f76f-4e45-8572-147541079bb5        1488.0
# 2            2  020bce8e-f76f-4e45-8572-147541079bb5        2772.0
# 3            3  020bce8e-f76f-4e45-8572-147541079bb5        1116.0
# 4            4  020bce8e-f76f-4e45-8572-147541079bb5        3505.0
# 5            5  020bce8e-f76f-4e45-8572-147541079bb5        1438.0
# 6            6  020bce8e-f76f-4e45-8572-147541079bb5        2066.0
# 7            7  020bce8e-f76f-4e45-8572-147541079bb5        2959.0
# 8            8  020bce8e-f76f-4e45-8572-147541079bb5        1012.0
# 9            9  020bce8e-f76f-4e45-8572-147541079bb5        1298.0
# 10          10  020bce8e-f76f-4e45-8572-147541079bb5        2230.0
# 11          11  020bce8e-f76f-4e45-8572-147541079bb5        2870.0
# 12          12  020bce8e-f76f-4e45-8572-147541079bb5         168.0
# ...

# %%
short_data = data.sample(50)
short_data
# Out:
#         Unnamed: 0                               API_key  Unnamed: 0.1  \
# 404015        1841  92ad50fb-20c4-49cb-875a-2c9e4e979bcd         622.0
# 650014        1660  a728ab83-492c-45a7-9fcd-6211e236e2d4         368.0
# 98486         3173  cbce143f-7107-42e5-b516-c8bd31753b0b        2535.0
# 180403        1352  86e26d6c-b701-490b-ada1-ace1899ee4bb         102.0
# 761365         156  085e24a9-d403-4ff3-af53-2e01d4506d2f         424.0
# 560784        4572  ec09446e-7ad9-40fa-9d47-289cfffee305        1480.0
# 165814        2716  bf761fdb-786f-4c23-9db8-5b481c3fcd19        2253.0
# 594927        1719  81215797-6215-4790-8307-4ef27b354703        3435.0
# 363478        1806  8ae9681c-bd05-4af5-8708-e74f45d3489b        2482.0
# 450985        1941  946c76c1-0fe2-47b4-871d-6d8a4a03ab74        2390.0
# 175853        2106  f7fccddd-51c7-422f-9f7f-f8e6c0f1e4c0        1705.0
# 391301        2241  ff696cea-d6f8-40a9-acde-cf997dd9bc7e         513.0
# ...

# %%
column_data
# Out:
#                                domain  \
# 559166                www.youtube.com
# 757274                  www.google.nl
# 733978               www.facebook.com
# 657461            clients5.google.com
# 575684                   forum.fok.nl
# 538824                   www.ziggo.nl
# 778017              www.mediamarkt.nl
# 55067                  www.blokker.nl
# 589528                  www.google.nl
# 328032                  www.google.nl
# 633058             www.marktplaats.nl
# 315654               www.facebook.com
# 415584  safebrowsing-cache.google.com
# 752279                  www.google.nl
# 295544                    www.bol.com
# 628580                 www.bonprix.nl
# 311469                      www.nu.nl
# 198725                  www.google.nl
# 88815              www.aliexpress.com
# 423339                www.youtube.com
# 650263                www.youtube.com
# 553770                 www.zalando.nl
# 598222            comments.dumpert.nl
# ...
